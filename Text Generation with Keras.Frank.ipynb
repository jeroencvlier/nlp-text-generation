# %%
# Using Keras to generate text based on the Dutch Novela "Wolfsjong"

# %%
import numpy
import sys
import keras
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
import nltk
nltk.download('stopwords')
import os
import warnings
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file = open("/content/drive/MyDrive/Colab Notebooks/wolfsjong/wolfsjong-kevin-van-vliet.txt").read()

# %%
def tokenize_words(input):
    input = input.lower()
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(input)
    filtered = filter(lambda token: token not in stopwords.words('dutch'), tokens)
    return " ".join(filtered)

# %%
processed_inputs = tokenize_words(file)
chars = sorted(list(set(processed_inputs)))
char_to_num = dict((c, i) for i, c in enumerate(chars))
num_to_char = dict((i, c) for i, c in enumerate(chars))

# %%
input_len = len(processed_inputs)
vocab_len = len(chars)
print ("Total no. of characters:", input_len)
print ("Total vocabulary:", vocab_len)
# Out:
# Total no. of characters: 65917
# Total vocabulary: 42

# %%
seq_length = 50
steps = 3
x_data = []
y_data = []

# %%
for i in range(0, input_len - seq_length, steps):
    in_seq = processed_inputs[i:i + seq_length]
    out_seq = processed_inputs[i + seq_length]
    x_data.append([char_to_num[char] for char in in_seq])
    y_data.append(char_to_num[out_seq])

# %%
n_patterns = len(x_data)
print ("Total Patterns:", n_patterns)
# Out:
# Total Patterns: 21956

# %%
X = numpy.reshape(x_data, (n_patterns, seq_length, 1))
X = X/float(vocab_len)

# %%
y = np_utils.to_categorical(y_data)

# %%
def create_model_v1():
    model = Sequential()
    model.add(LSTM(256, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(256, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(128))
    model.add(Dropout(0.2))
    model.add(Dense(y.shape[1], activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam')

    return model

# %%
check_point_filepath = "/content/drive/MyDrive/Colab Notebooks/wolfsjong/weights_checkpoint/wolfsjong_check_point"
checkpoint_dir = os.path.dirname(check_point_filepath)
model_checkpoint = ModelCheckpoint(filepath=check_point_filepath,monitor="loss",save_weights_only=False,mode='min',save_best_only=True)
desired_callbacks = [model_checkpoint]

# %%
# Check for previously trained model
if os.path.exists(check_point_filepath):
  print("Loading pre-existing model")
  model = keras.models.load_model(check_point_filepath)
else:
  print("Creating new model")
  model = create_model_v1()


model.fit(X, y, epochs=5, batch_size=256 ,callbacks=desired_callbacks,verbose=1)
# Out:
# Loading pre-existing model
# Epoch 1/5
# 86/86 [==============================] - 7s 39ms/step - loss: 0.2173
# Epoch 2/5
# 86/86 [==============================] - 3s 39ms/step - loss: 0.2494
# Epoch 3/5
# 86/86 [==============================] - 3s 39ms/step - loss: 0.2048
# Epoch 4/5
# 86/86 [==============================] - 3s 40ms/step - loss: 0.1776
# Epoch 5/5
# 86/86 [==============================] - 3s 40ms/step - loss: 0.1796

# %%
seed1 = 'Oskars woonboerderij was eigenlijk nauwelijks ingericht '
seed2 = 'Heuvele aan Zee had veel maar niets van dit alles '
seed3 = 'Hij had een zeer tragisch maar buitengewoon leven '

# %%
for seed in [seed1,seed2,seed3]:
  print("\n Seed phrase:..... ",seed )
  pattern = [char_to_num[value] for value in seed.lower()]
  for i in range(400):
    x = numpy.reshape(pattern, (1, len(pattern), 1))
    x = x / float(vocab_len)
    prediction = model.predict(x, verbose=0)
    index = numpy.argmax(prediction)
    result = num_to_char[index]
    seq_in = [num_to_char[value] for value in pattern]
    sys.stdout.write(result)
    pattern.append(index)
    pattern = pattern[1:len(pattern)]
  print("")
# Out:
#  Seed phrase:.....  Oskars woonboerderij was eigenlijk nauwelijks ingericht
# tteetder kerer gnefëerdr draahtog schijken wouden oueerigkd eeziten koest oodetekdn benloottakien staan vroed ptechtig lieten terdagt tton bers auten waar vindens oassen strn beeo o gegen gestal buur bviten veggen lietend lnege helijkkisbrs sahen hanp kauar mam spaak lanner maamte vijt verbrmen oes vet éouten ouderlijk luiste bleen jee latieer bieen feee zint alieen joodenmant aestond oottoeete ha
#
#  Seed phrase:.....  Heuvele aan Zee had veel maar niets van dit alles
# waar oukar kaak luielijk lee zeet geleten ai vrinve opraeende kokel stelken wel oasinter godde goord puaat veer laar geberrd vriend verben bezone oiemagd mee gezeten keek jiefn boereng blauwen zonden vel sielenhuis zetden droed oskar schren oukar maam oukar visls beeon alondi velde zel weer tteene bestelde gondinte kange eezatten druper juu kangen graag kann gezeten hrnpdnd gellrr zet blondi kangs
#
#  Seed phrase:.....  Hij had een zeer tragisch maar buitengewoon leven
# bleef kooijten hewel haan slaap soofgen zelfs blekkouies meeg gelwaglee handen verden gesedr trond voorwaast oagerzchoip belooftte kan gestotttve hestaal zitten zeler heleeen naam nntaal pskar adhterroonwen huis gevonn werzaaht aiauwen zel wiel geeut outentij be verk af fiebek joogensen eoe vonrde oan bezeld gofdensoot miem verzaaht mieg goorde vijt stee wijde wel weeg oleerber vteemde beziten lev
